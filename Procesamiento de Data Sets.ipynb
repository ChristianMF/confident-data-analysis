# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
#1

# %%
#1-M-19NOV-0800-0835-3A
df1M = spark.read.options(inferSchema=True, multiLine=True, delimiter="},", header=False).json("/Users/christian/Desktop/Data/1-M-19NOV-0800-0835-3A.json")

# %%
#Normalización 1-M-19NOV-0800-0835-3A
df1M=spark.createDataFrame(df1M.collect()[0])
a=[]
b=[]
c=[]
d=[]
e='3A'
def normaliza(data_structure):
    f=1
    for (index, item) in enumerate(data_structure):
        a.append(data_structure.collect()[0][index][0])
        b.append(data_structure.collect()[0][index][1])
        c.append(f)
        d.append(e)
        
        f+=1
    return data_structure

g=[]
def normalizaWithDate(data_structure):
    h=0
    for row in data_structure.collect():
        g.append(data_structure.select(data_structure.user.substr(23,43)).collect()[h][0])
        h+=1
    return data_structure

dftest=normaliza(df1M)
df1M=spark.createDataFrame(zip(c, a, b, d), schema=['no','text','user','group'])

dftest=normalizaWithDate(df1M)
df1M=spark.createDataFrame(zip(c, a, b, g, d), schema=['no','text','user','date','group'])

df1M.show()
df1M.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  2|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  3|Okay, Fer 🙃 ¿Me ...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  4|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  5|Excelente 👌, aho...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  6|¿Quieres comenzar...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  7|Sí acepto los tér...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  8|¿Qué tema quieres...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  9|¿Cómo te ves en 2...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# | 10|¿Qué preferirías?...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# ...

# %%
#Resultado 1-19NOV-0800-0835-3A

#Dataframe generico de interacciones
df1 = df1M
df1.show()

#Dataframe de usuarios registrados


#Dataframe de ¿por qué no sirvió?
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  2|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  3|Okay, Fer 🙃 ¿Me ...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  4|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  5|Excelente 👌, aho...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  6|¿Quieres comenzar...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  7|Sí acepto los tér...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  8|¿Qué tema quieres...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  9|¿Cómo te ves en 2...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# | 10|¿Qué preferirías?...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# ...

# %%
#2

# %%
#2-M-27NOV-1140-1252-1A
df2M = spark.read.options(inferSchema=True, multiLine=True, delimiter="},", header=False).json("/Users/christian/Desktop/Data/2-M-27NOV-1140-1252-1A.json")

# %%
#Normalización 2-M-27NOV-1140-1252-1A
df2M=spark.createDataFrame(df2M.collect()[0])
a=[]
b=[]
c=[]
d=[]
e='1A'
def normaliza(data_structure):
    f=1
    for (index, item) in enumerate(data_structure):
        a.append(data_structure.collect()[0][index][0])
        b.append(data_structure.collect()[0][index][1])
        c.append(f)
        d.append(e)
        
        f+=1
    return data_structure

g=[]
def normalizaWithDate(data_structure):
    h=0
    for row in data_structure.collect():
        g.append(data_structure.select(data_structure.user.substr(23,43)).collect()[h][0])
        h+=1
    return data_structure

dftest=normaliza(df2M)
df2M=spark.createDataFrame(zip(c, a, b, d), schema=['no','text','user','group'])

dftest=normalizaWithDate(df2M)
df2M=spark.createDataFrame(zip(c, a, b, g, d), schema=['no','text','user','date','group'])

df2M.show()
df2M.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|No acepto los tér...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  2|1.2.5 ¿Aún así qu...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  3|Sí acepto los tér...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  4|✌️ 😄 para comenz...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  5|Okay, Jesús Ricar...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  6|✌️ 😄 para comenz...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  7|Sí acepto los tér...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  8|Sí acepto los tér...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  9|✌️ 😄 para comenz...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# | 10|Okay, Uriel 🙃 ¿M...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# ...

# %%
#2-W-27NOV-1140-1252-1A
df2WT = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/2-W-text-27NOV-1140-1252-1A.json")
df2WR = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/2-W-registrations-27NOV-1140-1252-1A.json")
df2WF = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/2-W-functionalities-27NOV-1140-1252-1A.json")

# %%
#Normalización 2-WT-27NOV-1140-1252-1A

a=[]
b=[]
c=[]
d=[]
e=[]
f='1A'

def normaliza(data_structure):
    g=1
    h=0
    for row in data_structure.collect():
        a.append(str(data_structure.select("text").collect()[h][0]))
        b.append(str(data_structure.select("id_user").collect()[h][0]))
        e.append(str(data_structure.select("date").collect()[h][0][0]))
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
    return data_structure

dftest=normaliza(df2WT)

df2WT=spark.createDataFrame(zip(c, a, b, e, d), schema=['no','text','user','date','group'])
df2WT.show()
df2WT.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|c6aab91d-199c-46d...|2020-11-27T17:53:...|   1A|
# |  2|Sí acepto los tér...|adceba94-5278-4af...|2020-11-27T17:54:...|   1A|
# |  3|            Landeros|c6aab91d-199c-46d...|2020-11-27T17:54:...|   1A|
# |  4|                  12|c6aab91d-199c-46d...|2020-11-27T17:54:...|   1A|
# |  5|Sí acepto los tér...|fbff4567-a52e-4cf...|2020-11-27T17:54:...|   1A|
# |  6|              Hombre|c6aab91d-199c-46d...|2020-11-27T17:54:...|   1A|
# |  7|Sí acepto los tér...|8c88a131-9a11-4fd...|2020-11-27T17:54:...|   1A|
# |  8|Sí acepto los tér...|adceba94-5278-4af...|2020-11-27T17:54:...|   1A|
# |  9|             Abigail|fbff4567-a52e-4cf...|2020-11-27T17:54:...|   1A|
# ...

# %%
#Normalización 2-WR-27NOV-1140-1252-1A

a=[]
v=[]
c=[]
d=[]
y=[]
z=[]
f='1A'

def normaliza(data_structure):
    g=1
    h=0
    r=(data_structure.count()*4)
    for x in range(r):
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'age '+str(data_structure.select("age").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'community '+str(data_structure.select("community").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'gender '+str(data_structure.select("gender").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'name '+str(data_structure.select("name").collect()[h][0])])
        
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
        if h >= data_structure.count():
            h=0
    return data_structure

def normalizaSeparate(data_structure):
    l=0
    r=data_structure.count()
    for x in range(r):
        v.append(str(data_structure.select("text").collect()[l][0][0]))
        y.append(str(data_structure.select("text").collect()[l][0][1]))
        z.append(str(data_structure.select("text").collect()[l][0][2]))        
        
        l+=1
    return data_structure

dftest=normaliza(df2WR)
df2WR=spark.createDataFrame(zip(c, a , d), schema=['no','text','group'])

dftest=normalizaSeparate(df2WR)
df2WR=spark.createDataFrame(zip(c, z, v, y, d), schema=['no','text','user','date','group'])

df2WR.show()
df2WR.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|              age 12|5fc13d70507d9c001...|registrationDate ...|   1A|
# |  2|community Es boni...|5fc13d70507d9c001...|registrationDate ...|   1A|
# |  3|       gender Hombre|5fc13d70507d9c001...|registrationDate ...|   1A|
# |  4|       name Landeros|5fc13d70507d9c001...|registrationDate ...|   1A|
# |  5|              age 12|5fc13d7a507d9c001...|registrationDate ...|   1A|
# |  6|   community Zapopan|5fc13d7a507d9c001...|registrationDate ...|   1A|
# |  7|       gender Hombre|5fc13d7a507d9c001...|registrationDate ...|   1A|
# |  8|         name Emilio|5fc13d7a507d9c001...|registrationDate ...|   1A|
# |  9|              age 12|5fc13d80507d9c001...|registrationDate ...|   1A|
# ...

# %%
#Normalización 2-WF-27NOV-1140-1252-1A

df2WF.show()
df2WF.summary().show()
# Out:
# ++
# ||
# ++
# ++
#
# +-------+
# |summary|
# +-------+
# |  count|
# |   mean|
# | stddev|
# |    min|
# |    25%|
# |    50%|
# |    75%|
# |    max|
# +-------+

# %%
#Resultado 2-27NOV-1140-1252-1A

#Dataframe generico de interacciones
df2 = df2M.union(df2WT);
df2 = df2.drop("no")

i=[]
a=[]
b=[]
c=[]
d=[]
def index(data_structure):
    e=1
    for x in range(data_structure.count()):
        i.append(e)
        a.append(data_structure.select("text").collect()[x][0])
        b.append(data_structure.select("user").collect()[x][0])
        c.append(data_structure.select("date").collect()[x][0])
        d.append(data_structure.select("group").collect()[x][0])
        e+=1
    
    return data_structure

index(df2)
df2=spark.createDataFrame(zip(i, a, b, c, d), schema=['no','text','user','date','group'])
df2.show(500)

#Dataframe de usuarios registrados
df2WR.show()

#Dataframe de ¿por qué no sirvió?
df2WF.show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|No acepto los tér...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  2|1.2.5 ¿Aún así qu...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  3|Sí acepto los tér...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  4|✌️ 😄 para comenz...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  5|Okay, Jesús Ricar...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  6|✌️ 😄 para comenz...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  7|Sí acepto los tér...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  8|Sí acepto los tér...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  9|✌️ 😄 para comenz...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# | 10|Okay, Uriel 🙃 ¿M...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# ...

# %%
#3

# %%
#3-M-01DIC-0700-0735-2A
df3M = spark.read.options(inferSchema=True, multiLine=True, delimiter="},", header=False).json("/Users/christian/Desktop/Data/3-M-01DIC-0700-0735-2A.json")

# %%
#Normalización 3-M-01DIC-0700-0735-2A
df3M=spark.createDataFrame(df3M.collect()[0])
a=[]
b=[]
c=[]
d=[]
e='2A'
def normaliza(data_structure):
    f=1
    for (index, item) in enumerate(data_structure):
        a.append(data_structure.collect()[0][index][0])
        b.append(data_structure.collect()[0][index][1])
        c.append(f)
        d.append(e)
        
        f+=1
    return data_structure

g=[]
def normalizaWithDate(data_structure):
    h=0
    for row in data_structure.collect():
        g.append(data_structure.select(data_structure.user.substr(23,43)).collect()[h][0])
        h+=1
    return data_structure

dftest=normaliza(df3M)
df3M=spark.createDataFrame(zip(c, a, b, d), schema=['no','text','user','group'])

dftest=normalizaWithDate(df3M)
df3M=spark.createDataFrame(zip(c, a, b, g, d), schema=['no','text','user','date','group'])

df3M.show()
df3M.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  2|✌️ 😄 para comenz...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  3|Okay, Karol Misae...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  4|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  5|Excelente 👌, aho...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  6|¿Quieres comenzar...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  7|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  8|✌️ 😄 para comenz...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  9|Okay, Fabio 🙃 ¿M...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# | 10|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# ...

# %%
#3-W-01DIC-0700-0735-2A
df3WT = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/3-W-text-01DIC-0700-0735-2A.json")
df3WR = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/3-W-registrations-01DIC-0700-0735-2A.json")
df3WF = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/3-W-functionalities-01DIC-0700-0735-2A.json")

# %%
#Normalización 3-WT-01DIC-0700-0735-2A

a=[]
b=[]
c=[]
d=[]
e=[]
f='2A'

def normaliza(data_structure):
    g=1
    h=0
    for row in data_structure.collect():
        a.append(str(data_structure.select("text").collect()[h][0]))
        b.append(str(data_structure.select("id_user").collect()[h][0]))
        e.append(str(data_structure.select("date").collect()[h][0][0]))
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
    return data_structure

dftest=normaliza(df3WT)

df3WT=spark.createDataFrame(zip(c, a, b, e, d), schema=['no','text','user','date','group'])
df3WT.show()
df3WT.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|93e61cdb-f371-411...|2020-12-01T13:10:...|   2A|
# |  2|              victor|93e61cdb-f371-411...|2020-12-01T13:10:...|   2A|
# |  3|                  13|93e61cdb-f371-411...|2020-12-01T13:10:...|   2A|
# |  4|              hombre|93e61cdb-f371-411...|2020-12-01T13:11:...|   2A|
# |  5|                  no|93e61cdb-f371-411...|2020-12-01T13:11:...|   2A|
# |  6|¿Quieres comenzar...|93e61cdb-f371-411...|2020-12-01T13:11:...|   2A|
# |  7|¿Qué tema quieres...|93e61cdb-f371-411...|2020-12-01T13:13:...|   2A|
# |  8|¿Cómo te ves en 2...|93e61cdb-f371-411...|2020-12-01T13:13:...|   2A|
# |  9|¿Qué estudias act...|93e61cdb-f371-411...|2020-12-01T13:14:...|   2A|
# ...

# %%
#Normalización 3-WR-01DIC-0700-0735-2A

a=[]
v=[]
c=[]
d=[]
y=[]
z=[]
f='2A'

def normaliza(data_structure):
    g=1
    h=0
    r=(data_structure.count()*4)
    for x in range(r):
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'age '+str(data_structure.select("age").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'community '+str(data_structure.select("community").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'gender '+str(data_structure.select("gender").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'name '+str(data_structure.select("name").collect()[h][0])])
        
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
        if h >= data_structure.count():
            h=0
    return data_structure

def normalizaSeparate(data_structure):
    l=0
    r=data_structure.count()
    for x in range(r):
        v.append(str(data_structure.select("text").collect()[l][0][0]))
        y.append(str(data_structure.select("text").collect()[l][0][1]))
        z.append(str(data_structure.select("text").collect()[l][0][2]))        
        
        l+=1
    return data_structure

dftest=normaliza(df3WR)
df3WR=spark.createDataFrame(zip(c, a , d), schema=['no','text','group'])

dftest=normalizaSeparate(df3WR)
df3WR=spark.createDataFrame(zip(c, z, v, y, d), schema=['no','text','user','date','group'])

df3WR.show()
df3WR.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|              age 13|5fc640fa698192001...|registrationDate ...|   2A|
# |  2|        community no|5fc640fa698192001...|registrationDate ...|   2A|
# |  3|       gender hombre|5fc640fa698192001...|registrationDate ...|   2A|
# |  4|         name victor|5fc640fa698192001...|registrationDate ...|   2A|
# |  5|              age 46|5fc6452e698192001...|registrationDate ...|   2A|
# |  6|community Ameca j...|5fc6452e698192001...|registrationDate ...|   2A|
# |  7|       gender Hombre|5fc6452e698192001...|registrationDate ...|   2A|
# |  8|name Jorge Enriqu...|5fc6452e698192001...|registrationDate ...|   2A|
# +---+--------------------+--------------------+--------------------+-----+
#
# ...

# %%
#Normalización 3-WF-01DIC-0700-0735-2A

df3WF.show()
df3WF.summary().show()
# Out:
# ++
# ||
# ++
# ++
#
# +-------+
# |summary|
# +-------+
# |  count|
# |   mean|
# | stddev|
# |    min|
# |    25%|
# |    50%|
# |    75%|
# |    max|
# +-------+

# %%
#Resultado 3-01DIC-0700-0735-2A

#Dataframe generico de interacciones
df3 = df3M.union(df3WT);
df3 = df3.drop("no")

i=[]
a=[]
b=[]
c=[]
d=[]
def index(data_structure):
    e=1
    for x in range(data_structure.count()):
        i.append(e)
        a.append(data_structure.select("text").collect()[x][0])
        b.append(data_structure.select("user").collect()[x][0])
        c.append(data_structure.select("date").collect()[x][0])
        d.append(data_structure.select("group").collect()[x][0])
        e+=1
    
    return data_structure

index(df3)
df3=spark.createDataFrame(zip(i, a, b, c, d), schema=['no','text','user','date','group'])
df3.show(500)

#Dataframe de usuarios registrados
df3WR.show()

#Dataframe de ¿por qué no sirvió?
df3WF.show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  2|✌️ 😄 para comenz...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  3|Okay, Karol Misae...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  4|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  5|Excelente 👌, aho...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  6|¿Quieres comenzar...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  7|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  8|✌️ 😄 para comenz...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# |  9|Okay, Fabio 🙃 ¿M...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# | 10|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Tue Dec 01 2020 0...|   2A|
# ...

# %%
#4

# %%
#4-M-01IDC-1050-1112-2B
df4M = spark.read.options(inferSchema=True, multiLine=True, delimiter="},", header=False).json("/Users/christian/Desktop/Data/4-M-01IDC-1050-1112-2B.json")

# %%
#Normalización 4-M-01IDC-1050-1112-2B
df4M=spark.createDataFrame(df4M.collect()[0])
a=[]
b=[]
c=[]
d=[]
e='2B'
def normaliza(data_structure):
    f=1
    for (index, item) in enumerate(data_structure):
        a.append(data_structure.collect()[0][index][0])
        b.append(data_structure.collect()[0][index][1])
        c.append(f)
        d.append(e)
        
        f+=1
    return data_structure

g=[]
def normalizaWithDate(data_structure):
    h=0
    for row in data_structure.collect():
        g.append(data_structure.select(data_structure.user.substr(23,43)).collect()[h][0])
        h+=1
    return data_structure

dftest=normaliza(df4M)
df4M=spark.createDataFrame(zip(c, a, b, d), schema=['no','text','user','group'])

dftest=normalizaWithDate(df4M)
df4M=spark.createDataFrame(zip(c, a, b, g, d), schema=['no','text','user','date','group'])

df4M.show()
df4M.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  2|✌️ 😄 para comenz...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  3|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  4|Okay, Juan Pablo ...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  5|✌️ 😄 para comenz...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  6|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  7|Okay, Samuel 🙃 ¿...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  8|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  9|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# | 10|✌️ 😄 para comenz...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# ...

# %%
#4-W-01IDC-1050-1112-2B
df4WT = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/4-W-text-01IDC-1050-1112-2B.json")
df4WR = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/4-W-registrations-01IDC-1050-1112-2B.json")
df4WF = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/4-W-functionalities-01IDC-1050-1112-2B.json")

# %%
#Normalización 4-WT-01IDC-1050-1112-2B

a=[]
b=[]
c=[]
d=[]
e=[]
f='2B'

def normaliza(data_structure):
    g=1
    h=0
    for row in data_structure.collect():
        a.append(str(data_structure.select("text").collect()[h][0]))
        b.append(str(data_structure.select("id_user").collect()[h][0]))
        e.append(str(data_structure.select("date").collect()[h][0][0]))
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
    return data_structure

dftest=normaliza(df4WT)

df4WT=spark.createDataFrame(zip(c, a, b, e, d), schema=['no','text','user','date','group'])
df4WT.show()
df4WT.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|ce488ed5-fe52-4d1...|2020-12-01T16:56:...|   2B|
# |  2|No acepto los tér...|b7383fb9-15f4-4f1...|2020-12-01T16:57:...|   2B|
# |  3|1.2.5 ¿Aún así qu...|b7383fb9-15f4-4f1...|2020-12-01T16:57:...|   2B|
# |  4|Sí acepto los tér...|274b30b7-2d21-4dc...|2020-12-01T16:57:...|   2B|
# |  5|                Said|274b30b7-2d21-4dc...|2020-12-01T16:57:...|   2B|
# |  6|Sí acepto los tér...|f3957cae-1150-444...|2020-12-01T16:58:...|   2B|
# |  7|              Arelys|b7383fb9-15f4-4f1...|2020-12-01T16:58:...|   2B|
# |  8|                  13|b7383fb9-15f4-4f1...|2020-12-01T16:58:...|   2B|
# |  9|               Mujer|b7383fb9-15f4-4f1...|2020-12-01T16:59:...|   2B|
# ...

# %%
#Normalización 4-WR-01IDC-1050-1112-2B

a=[]
v=[]
c=[]
d=[]
y=[]
z=[]
f='2B'

def normaliza(data_structure):
    g=1
    h=0
    r=(data_structure.count()*4)
    for x in range(r):
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'age '+str(data_structure.select("age").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'community '+str(data_structure.select("community").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'gender '+str(data_structure.select("gender").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'name '+str(data_structure.select("name").collect()[h][0])])
        
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
        if h >= data_structure.count():
            h=0
    return data_structure

def normalizaSeparate(data_structure):
    l=0
    r=data_structure.count()
    for x in range(r):
        v.append(str(data_structure.select("text").collect()[l][0][0]))
        y.append(str(data_structure.select("text").collect()[l][0][1]))
        z.append(str(data_structure.select("text").collect()[l][0][2]))        
        
        l+=1
    return data_structure

dftest=normaliza(df4WR)
df4WR=spark.createDataFrame(zip(c, a , d), schema=['no','text','group'])

dftest=normalizaSeparate(df4WR)
df4WR=spark.createDataFrame(zip(c, z, v, y, d), schema=['no','text','user','date','group'])

df4WR.show()
df4WR.summary().show()
# Out:
# +---+-----------------+--------------------+--------------------+-----+
# | no|             text|                user|                date|group|
# +---+-----------------+--------------------+--------------------+-----+
# |  1|      age 13 años|5fc676e0b863e8001...|registrationDate ...|   2B|
# |  2|community Zapopan|5fc676e0b863e8001...|registrationDate ...|   2B|
# |  3|    gender Hombre|5fc676e0b863e8001...|registrationDate ...|   2B|
# |  4|        name said|5fc676e0b863e8001...|registrationDate ...|   2B|
# |  5|           age 13|5fc677b6b863e8001...|registrationDate ...|   2B|
# |  6|community Zapopan|5fc677b6b863e8001...|registrationDate ...|   2B|
# |  7|     gender Mujer|5fc677b6b863e8001...|registrationDate ...|   2B|
# |  8|     name Valeria|5fc677b6b863e8001...|registrationDate ...|   2B|
# |  9|           age 13|5fc677c5b863e8001...|registrationDate ...|   2B|
# | 10|community chiapas|5fc677c5b863e8001...|registrationDate ...|   2B|
# ...

# %%
#Normalización 4-WF-01IDC-1050-1112-2B

a=[]
b=[]
c=[]
d=[]
e=[]
f='2B'

def normaliza(data_structure):
    g=1
    h=0
    for row in data_structure.collect():
        a.append(str(data_structure.collect()[0][1][h]))
        b.append(str('functionality ' + data_structure.select("functionality").collect()[0][h]))
        e.append(str(data_structure.collect()[0][3][h]))
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
    return data_structure

dftest=normaliza(df4WF)

df4WF=spark.createDataFrame(zip(c, b, a, e, d), schema=['no','text','user','date','group'])
df4WF.show()
df4WF.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|functionality Por...|5fc67867b863e8001...|2020-12-01T17:07:...|   2B|
# +---+--------------------+--------------------+--------------------+-----+
#
# +-------+---+--------------------+--------------------+--------------------+-----+
# |summary| no|                text|                user|                date|group|
# +-------+---+--------------------+--------------------+--------------------+-----+
# |  count|  1|                   1|                   1|                   1|    1|
# |   mean|1.0|                null|                null|                null| null|
# | stddev|NaN|                null|                null|                null| null|
# |    min|  1|functionality Por...|5fc67867b863e8001...|2020-12-01T17:07:...|   2B|
# ...

# %%
#Resultado 4-01IDC-1050-1112-2B

#Dataframe generico de interacciones
df4 = df4M.union(df4WT);
df4 = df4.drop("no")

i=[]
a=[]
b=[]
c=[]
d=[]
def index(data_structure):
    e=1
    for x in range(data_structure.count()):
        i.append(e)
        a.append(data_structure.select("text").collect()[x][0])
        b.append(data_structure.select("user").collect()[x][0])
        c.append(data_structure.select("date").collect()[x][0])
        d.append(data_structure.select("group").collect()[x][0])
        e+=1
    
    return data_structure

index(df4)
df4=spark.createDataFrame(zip(i, a, b, c, d), schema=['no','text','user','date','group'])
df4.show(500)

#Dataframe de usuarios registrados
df4WR.show()

#Dataframe de ¿por qué no sirvió?
df4WF.show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  2|✌️ 😄 para comenz...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  3|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  4|Okay, Juan Pablo ...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  5|✌️ 😄 para comenz...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  6|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  7|Okay, Samuel 🙃 ¿...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  8|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# |  9|Sí acepto los tér...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# | 10|✌️ 😄 para comenz...|mobile_app_dialog...|Tue Dec 01 2020 1...|   2B|
# ...

# %%
#5

# %%
#5-M-03DIC-0930-1005-1C
df5M = spark.read.options(inferSchema=True, multiLine=True, delimiter="},", header=False).json("/Users/christian/Desktop/Data/5-M-03DIC-0930-1005-1C.json")

# %%
#Normalización 5-M-03DIC-0930-1005-1C
df5M=spark.createDataFrame(df5M.collect()[0])
a=[]
b=[]
c=[]
d=[]
e='1C'
def normaliza(data_structure):
    f=1
    for (index, item) in enumerate(data_structure):
        a.append(data_structure.collect()[0][index][0])
        b.append(data_structure.collect()[0][index][1])
        c.append(f)
        d.append(e)
        
        f+=1
    return data_structure

g=[]
def normalizaWithDate(data_structure):
    h=0
    for row in data_structure.collect():
        g.append(data_structure.select(data_structure.user.substr(23,43)).collect()[h][0])
        h+=1
    return data_structure

dftest=normaliza(df5M)
df5M=spark.createDataFrame(zip(c, a, b, d), schema=['no','text','user','group'])

dftest=normalizaWithDate(df5M)
df5M=spark.createDataFrame(zip(c, a, b, g, d), schema=['no','text','user','date','group'])

df5M.show()
df5M.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  2|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  3|Okay, Ximena 🙃 ¿...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  4|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  5|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  6|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  7|Excelente 👌, aho...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  8|¿Quieres comenzar...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  9|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# | 10|¿Qué tema quieres...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# ...

# %%
#5-W-03DIC-0930-1005-1C
df5WT = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/5-W-text-03DIC-0930-1005-1C.json")
df5WR = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/5-W-registrations-03DIC-0930-1005-1C.json")
df5WF = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/5-W-functionalities-03DIC-0930-1005-1C.json")

# %%
#Normalización 5-WT-03DIC-0930-1005-1C

a=[]
b=[]
c=[]
d=[]
e=[]
f='1C'

def normaliza(data_structure):
    g=1
    h=0
    for row in data_structure.collect():
        a.append(str(data_structure.select("text").collect()[h][0]))
        b.append(str(data_structure.select("id_user").collect()[h][0]))
        e.append(str(data_structure.select("date").collect()[h][0][0]))
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
    return data_structure

dftest=normaliza(df5WT)

df5WT=spark.createDataFrame(zip(c, a, b, e, d), schema=['no','text','user','date','group'])
df5WT.show()
df5WT.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|85ca1b92-bb3c-4db...|2020-12-03T15:42:...|   1C|
# |  2|            ok angel|85ca1b92-bb3c-4db...|2020-12-03T15:42:...|   1C|
# |  3|           eee si 12|85ca1b92-bb3c-4db...|2020-12-03T15:42:...|   1C|
# |  4|                  no|85ca1b92-bb3c-4db...|2020-12-03T15:43:...|   1C|
# |  5|no pudo desir esa...|85ca1b92-bb3c-4db...|2020-12-03T15:43:...|   1C|
# |  6|¿Quieres comenzar...|85ca1b92-bb3c-4db...|2020-12-03T15:43:...|   1C|
# |  7|¿Qué tema quieres...|85ca1b92-bb3c-4db...|2020-12-03T15:44:...|   1C|
# |  8|¿Sobre qué tema t...|85ca1b92-bb3c-4db...|2020-12-03T15:44:...|   1C|
# |  9|¿Qué te gustaría ...|85ca1b92-bb3c-4db...|2020-12-03T15:44:...|   1C|
# ...

# %%
#Normalización 5-WR-03DIC-0930-1005-1C

a=[]
v=[]
c=[]
d=[]
y=[]
z=[]
f='1C'

def normaliza(data_structure):
    g=1
    h=0
    r=(data_structure.count()*4)
    for x in range(r):
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'age '+str(data_structure.select("age").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'community '+str(data_structure.select("community").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'gender '+str(data_structure.select("gender").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'name '+str(data_structure.select("name").collect()[h][0])])
        
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
        if h >= data_structure.count():
            h=0
    return data_structure

def normalizaSeparate(data_structure):
    l=0
    r=data_structure.count()
    for x in range(r):
        v.append(str(data_structure.select("text").collect()[l][0][0]))
        y.append(str(data_structure.select("text").collect()[l][0][1]))
        z.append(str(data_structure.select("text").collect()[l][0][2]))        
        
        l+=1
    return data_structure

dftest=normaliza(df5WR)
df5WR=spark.createDataFrame(zip(c, a , d), schema=['no','text','group'])

dftest=normalizaSeparate(df5WR)
df5WR=spark.createDataFrame(zip(c, z, v, y, d), schema=['no','text','user','date','group'])

df5WR.show()
df5WR.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|       age eee si 12|5fc907ae407252001...|registrationDate ...|   1C|
# |  2|community no pudo...|5fc907ae407252001...|registrationDate ...|   1C|
# |  3|           gender no|5fc907ae407252001...|registrationDate ...|   1C|
# |  4|       name ok angel|5fc907ae407252001...|registrationDate ...|   1C|
# |  5|              age 11|5fc909f8407252001...|registrationDate ...|   1C|
# |  6|   community zapopan|5fc909f8407252001...|registrationDate ...|   1C|
# |  7|        gender mujer|5fc909f8407252001...|registrationDate ...|   1C|
# |  8|  name andrea lizeth|5fc909f8407252001...|registrationDate ...|   1C|
# |  9|              age 12|5fc90a17407252001...|registrationDate ...|   1C|
# ...

# %%
#Normalización 5-WF-03DIC-0930-1005-1C

a=[]
b=[]
c=[]
d=[]
e=[]
f='1C'

def normaliza(data_structure):
    g=1
    h=0
    for row in data_structure.collect():
        a.append(str(data_structure.collect()[0][1][h]))
        b.append("functionality " + str(data_structure.select("functionality").collect()[0][h]))
        e.append(str(data_structure.collect()[0][3][h]))
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
    return data_structure

dftest=normaliza(df5WF)

df5WF=spark.createDataFrame(zip(c, b, a, e, d), schema=['no','text','user','date','group'])
df5WF.show()
df5WF.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|functionality por...|5fc90b7c407252001...|2020-12-03T15:59:...|   1C|
# +---+--------------------+--------------------+--------------------+-----+
#
# +-------+---+--------------------+--------------------+--------------------+-----+
# |summary| no|                text|                user|                date|group|
# +-------+---+--------------------+--------------------+--------------------+-----+
# |  count|  1|                   1|                   1|                   1|    1|
# |   mean|1.0|                null|                null|                null| null|
# | stddev|NaN|                null|                null|                null| null|
# |    min|  1|functionality por...|5fc90b7c407252001...|2020-12-03T15:59:...|   1C|
# ...

# %%
#Resultado 5-03DIC-0930-1005-1C

#Dataframe generico de interacciones
df5 = df5M.union(df5WT);
df5 = df5.drop("no")

i=[]
a=[]
b=[]
c=[]
d=[]
def index(data_structure):
    e=1
    for x in range(data_structure.count()):
        i.append(e)
        a.append(data_structure.select("text").collect()[x][0])
        b.append(data_structure.select("user").collect()[x][0])
        c.append(data_structure.select("date").collect()[x][0])
        d.append(data_structure.select("group").collect()[x][0])
        e+=1
    
    return data_structure

index(df5)
df5=spark.createDataFrame(zip(i, a, b, c, d), schema=['no','text','user','date','group'])
df5.show(500)

#Dataframe de usuarios registrados
df5WR.show()

#Dataframe de ¿por qué no sirvió?
df5WF.show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  2|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  3|Okay, Ximena 🙃 ¿...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  4|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  5|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  6|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  7|Excelente 👌, aho...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  8|¿Quieres comenzar...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# |  9|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# | 10|¿Qué tema quieres...|mobile_app_dialog...|Thu Dec 03 2020 0...|   1C|
# ...

# %%
#6

# %%
#6-M-03DIC-1050-1132-1B
df6M = spark.read.options(inferSchema=True, multiLine=True, delimiter="},", header=False).json("/Users/christian/Desktop/Data/6-M-03DIC-1050-1132-1B.json")

# %%
#Normalización 6-M-03DIC-1050-1132-1B
df6M=spark.createDataFrame(df6M.collect()[0])
a=[]
b=[]
c=[]
d=[]
e='1B'
def normaliza(data_structure):
    f=1
    for (index, item) in enumerate(data_structure):
        a.append(data_structure.collect()[0][index][0])
        b.append(data_structure.collect()[0][index][1])
        c.append(f)
        d.append(e)
        
        f+=1
    return data_structure

g=[]
def normalizaWithDate(data_structure):
    h=0
    for row in data_structure.collect():
        g.append(data_structure.select(data_structure.user.substr(23,43)).collect()[h][0])
        h+=1
    return data_structure

dftest=normaliza(df6M)
df6M=spark.createDataFrame(zip(c, a, b, d), schema=['no','text','user','group'])

dftest=normalizaWithDate(df6M)
df6M=spark.createDataFrame(zip(c, a, b, g, d), schema=['no','text','user','date','group'])

df6M.show()
df6M.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  2|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  3|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  4|Okay, Angel 🙃 ¿M...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  5|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  6|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  7|Okay, Carlos Leon...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  8|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  9|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# | 10|Okay, Juan pablo ...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# ...

# %%
#6-W-03DIC-1050-1132-1B
df6WT = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/6-W-text-03DIC-1050-1132-1B.json")
df6WR = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/6-W-registrations-03DIC-1050-1132-1B.json")
df6WF = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/6-W-functionalities-03DIC-1050-1132-1B.json")

# %%
#Normalización 6-WT-03DIC-1050-1132-1B

a=[]
b=[]
c=[]
d=[]
e=[]
f='1B'

def normaliza(data_structure):
    g=1
    h=0
    for row in data_structure.collect():
        a.append(str(data_structure.select("text").collect()[h][0]))
        b.append(str(data_structure.select("id_user").collect()[h][0]))
        e.append(str(data_structure.select("date").collect()[h][0][0]))
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
    return data_structure

dftest=normaliza(df6WT)

df6WT=spark.createDataFrame(zip(c, a, b, e, d), schema=['no','text','user','date','group'])
df6WT.show()
df6WT.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|d45d7c59-321e-424...|2020-12-03T17:04:...|   1B|
# |  2|Irvin jin han Ram...|d45d7c59-321e-424...|2020-12-03T17:05:...|   1B|
# |  3|Sí acepto los tér...|d45d7c59-321e-424...|2020-12-03T17:06:...|   1B|
# |  4|Irvin jin han Ram...|d45d7c59-321e-424...|2020-12-03T17:06:...|   1B|
# |  5|Sí acepto los tér...|d45d7c59-321e-424...|2020-12-03T17:08:...|   1B|
# |  6|Sí acepto los tér...|d45d7c59-321e-424...|2020-12-03T17:08:...|   1B|
# |  7|Irvin jin han Ram...|d45d7c59-321e-424...|2020-12-03T17:09:...|   1B|
# |  8|Sí acepto los tér...|83e21415-4c57-41b...|2020-12-03T17:12:...|   1B|
# |  9|Sí acepto los tér...|0d3d89d6-876f-490...|2020-12-03T17:14:...|   1B|
# ...

# %%
#Normalización 6-WR-03DIC-1050-1132-1B

a=[]
v=[]
c=[]
d=[]
y=[]
z=[]
f='1B'

def normaliza(data_structure):
    g=1
    h=0
    r=(data_structure.count()*4)
    for x in range(r):
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'age '+str(data_structure.select("age").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'community '+str(data_structure.select("community").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'gender '+str(data_structure.select("gender").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'name '+str(data_structure.select("name").collect()[h][0])])
        
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
        if h >= data_structure.count():
            h=0
    return data_structure

def normalizaSeparate(data_structure):
    l=0
    r=data_structure.count()
    for x in range(r):
        v.append(str(data_structure.select("text").collect()[l][0][0]))
        y.append(str(data_structure.select("text").collect()[l][0][1]))
        z.append(str(data_structure.select("text").collect()[l][0][2]))        
        
        l+=1
    return data_structure

dftest=normaliza(df6WR)
df6WR=spark.createDataFrame(zip(c, a , d), schema=['no','text','group'])

dftest=normalizaSeparate(df6WR)
df6WR=spark.createDataFrame(zip(c, z, v, y, d), schema=['no','text','user','date','group'])

df6WR.show()
df6WR.summary().show()
# Out:
# +---+-----------------+--------------------+--------------------+-----+
# | no|             text|                user|                date|group|
# +---+-----------------+--------------------+--------------------+-----+
# |  1|           age 12|5fc91d0fafa25f001...|registrationDate ...|   1B|
# |  2|community ZAPOPAN|5fc91d0fafa25f001...|registrationDate ...|   1B|
# |  3|     gender MUJER|5fc91d0fafa25f001...|registrationDate ...|   1B|
# |  4|   name QUETZALLI|5fc91d0fafa25f001...|registrationDate ...|   1B|
# |  5|           age no|5fc91d6cafa25f001...|registrationDate ...|   1B|
# |  6|community zapopan|5fc91d6cafa25f001...|registrationDate ...|   1B|
# |  7|        gender no|5fc91d6cafa25f001...|registrationDate ...|   1B|
# |  8|       name karla|5fc91d6cafa25f001...|registrationDate ...|   1B|
# +---+-----------------+--------------------+--------------------+-----+
#
# +-------+-----------------+----------+--------------------+--------------------+-----+
# ...

# %%
#Normalización 6-WF-03DIC-1050-1132-1B

df6WF.show()
df6WF.summary().show()
# Out:
# ++
# ||
# ++
# ++
#
# +-------+
# |summary|
# +-------+
# |  count|
# |   mean|
# | stddev|
# |    min|
# |    25%|
# |    50%|
# |    75%|
# |    max|
# +-------+

# %%
#Resultado 6-03DIC-1050-1132-1B

#Dataframe generico de interacciones
df6 = df6M.union(df6WT);
df6 = df6.drop("no")

i=[]
a=[]
b=[]
c=[]
d=[]
def index(data_structure):
    e=1
    for x in range(data_structure.count()):
        i.append(e)
        a.append(data_structure.select("text").collect()[x][0])
        b.append(data_structure.select("user").collect()[x][0])
        c.append(data_structure.select("date").collect()[x][0])
        d.append(data_structure.select("group").collect()[x][0])
        e+=1
    
    return data_structure

index(df6)
df6=spark.createDataFrame(zip(i, a, b, c, d), schema=['no','text','user','date','group'])
df6.show(500)

#Dataframe de usuarios registrados
df6WR.show()

#Dataframe de ¿por qué no sirvió?
df6WF.show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  2|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  3|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  4|Okay, Angel 🙃 ¿M...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  5|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  6|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  7|Okay, Carlos Leon...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  8|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# |  9|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# | 10|Okay, Juan pablo ...|mobile_app_dialog...|Thu Dec 03 2020 1...|   1B|
# ...

# %%
#7

# %%
#7-M-03DIC-1140-1214-3B
df7M = spark.read.options(inferSchema=True, multiLine=True, delimiter="},", header=False).json("/Users/christian/Desktop/Data/7-M-03DIC-1140-1214-3B.json")

# %%
#Normalización 7-M-03DIC-1140-1214-3B
df7M=spark.createDataFrame(df7M.collect()[0])
a=[]
b=[]
c=[]
d=[]
e='3B'
def normaliza(data_structure):
    f=1
    for (index, item) in enumerate(data_structure):
        a.append(data_structure.collect()[0][index][0])
        b.append(data_structure.collect()[0][index][1])
        c.append(f)
        d.append(e)
        
        f+=1
    return data_structure

g=[]
def normalizaWithDate(data_structure):
    h=0
    for row in data_structure.collect():
        g.append(data_structure.select(data_structure.user.substr(23,43)).collect()[h][0])
        h+=1
    return data_structure

dftest=normaliza(df7M)
df7M=spark.createDataFrame(zip(c, a, b, d), schema=['no','text','user','group'])

dftest=normalizaWithDate(df7M)
df7M=spark.createDataFrame(zip(c, a, b, g, d), schema=['no','text','user','date','group'])

df7M.show()
df7M.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  2|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  3|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  4|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  5|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  6|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  7|Okay, Lizbeth 🙃 ...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  8|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  9|Okay, Jhareli 🙃 ...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# | 10|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# ...

# %%
#7-W-03DIC-1140-1214-3B
df7WT = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/7-W-text-03DIC-1140-1214-3B.json")
df7WR = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/7-W-registrations-03DIC-1140-1214-3B.json")
df7WF = spark.read.options(inferSchema=True, multiLine=False, delimiter="\n", header=False).json("/Users/christian/Desktop/Data/7-W-functionalities-03DIC-1140-1214-3B.json")

# %%
#Normalización 7-WT-03DIC-1140-1214-3B

a=[]
b=[]
c=[]
d=[]
e=[]
f='3B'

def normaliza(data_structure):
    g=1
    h=0
    for row in data_structure.collect():
        a.append(str(data_structure.select("text").collect()[h][0]))
        b.append(str(data_structure.select("id_user").collect()[h][0]))
        e.append(str(data_structure.select("date").collect()[h][0][0]))
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
    return data_structure

dftest=normaliza(df7WT)

df7WT=spark.createDataFrame(zip(c, a, b, e, d), schema=['no','text','user','date','group'])
df7WT.show()
df7WT.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|f5a8854b-2596-47b...|2020-12-03T18:00:...|   3B|
# |  2|Sí acepto los tér...|58d7fd16-5f19-453...|2020-12-03T18:00:...|   3B|
# |  3|                King|58d7fd16-5f19-453...|2020-12-03T18:00:...|   3B|
# |  4|                  14|58d7fd16-5f19-453...|2020-12-03T18:01:...|   3B|
# |  5|              Hombre|58d7fd16-5f19-453...|2020-12-03T18:01:...|   3B|
# |  6|             Zapopan|58d7fd16-5f19-453...|2020-12-03T18:01:...|   3B|
# |  7|¿Quieres comenzar...|58d7fd16-5f19-453...|2020-12-03T18:01:...|   3B|
# |  8|¿Qué tema quieres...|58d7fd16-5f19-453...|2020-12-03T18:01:...|   3B|
# |  9|¿Cómo te ves en 2...|58d7fd16-5f19-453...|2020-12-03T18:01:...|   3B|
# ...

# %%
#Normalización 7-WR-03DIC-1140-1214-3B

a=[]
v=[]
c=[]
d=[]
y=[]
z=[]
f='3B'

def normaliza(data_structure):
    g=1
    h=0
    r=(data_structure.count()*4)
    for x in range(r):
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'age '+str(data_structure.select("age").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'community '+str(data_structure.select("community").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'gender '+str(data_structure.select("gender").collect()[h][0])])
        a.append([str(data_structure.select("_id").collect()[h][0][0]), 'registrationDate '+str(data_structure.select("registrationDate").collect()[h][0][0]), 'name '+str(data_structure.select("name").collect()[h][0])])
        
        c.append(g)
        d.append(f)
        
        g+=1
        h+=1
        if h >= data_structure.count():
            h=0
    return data_structure

def normalizaSeparate(data_structure):
    l=0
    r=data_structure.count()
    for x in range(r):
        v.append(str(data_structure.select("text").collect()[l][0][0]))
        y.append(str(data_structure.select("text").collect()[l][0][1]))
        z.append(str(data_structure.select("text").collect()[l][0][2]))        
        
        l+=1
    return data_structure

dftest=normaliza(df7WR)
df7WR=spark.createDataFrame(zip(c, a , d), schema=['no','text','group'])

dftest=normalizaSeparate(df7WR)
df7WR=spark.createDataFrame(zip(c, z, v, y, d), schema=['no','text','user','date','group'])

df7WR.show()
df7WR.summary().show()
# Out:
# +---+-----------------+--------------------+--------------------+-----+
# | no|             text|                user|                date|group|
# +---+-----------------+--------------------+--------------------+-----+
# |  1|           age 14|5fc927f3afa25f001...|registrationDate ...|   3B|
# |  2|community Zapopan|5fc927f3afa25f001...|registrationDate ...|   3B|
# |  3|    gender Hombre|5fc927f3afa25f001...|registrationDate ...|   3B|
# |  4|        name King|5fc927f3afa25f001...|registrationDate ...|   3B|
# +---+-----------------+--------------------+--------------------+-----+
#
# +-------+------------------+---------+--------------------+--------------------+-----+
# |summary|                no|     text|                user|                date|group|
# +-------+------------------+---------+--------------------+--------------------+-----+
# |  count|                 4|        4|                   4|                   4|    4|
# ...

# %%
#Normalización 7-WF-03DIC-1140-1214-3B

df7WF.show()
df7WF.summary().show()
# Out:
# ++
# ||
# ++
# ++
#
# +-------+
# |summary|
# +-------+
# |  count|
# |   mean|
# | stddev|
# |    min|
# |    25%|
# |    50%|
# |    75%|
# |    max|
# +-------+

# %%
#Resultado 7-03DIC-1140-1214-3B

#Dataframe generico de interacciones
df7 = df7M.union(df7WT);
df7 = df7.drop("no")

i=[]
a=[]
b=[]
c=[]
d=[]
def index(data_structure):
    e=1
    for x in range(data_structure.count()):
        i.append(e)
        a.append(data_structure.select("text").collect()[x][0])
        b.append(data_structure.select("user").collect()[x][0])
        c.append(data_structure.select("date").collect()[x][0])
        d.append(data_structure.select("group").collect()[x][0])
        e+=1
    
    return data_structure

index(df7)
df7=spark.createDataFrame(zip(i, a, b, c, d), schema=['no','text','user','date','group'])
df7.show(500)

#Dataframe de usuarios registrados
df7WR.show()

#Dataframe de ¿por qué no sirvió?
df7WF.show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  2|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  3|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  4|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  5|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  6|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  7|Okay, Lizbeth 🙃 ...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  8|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# |  9|Okay, Jhareli 🙃 ...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# | 10|Sí acepto los tér...|mobile_app_dialog...|Thu Dec 03 2020 1...|   3B|
# ...

# %%
#BD Policy Privacy de Cliente Página Web

# %%
#W-client-27NOV-04DIC
dfPPCW = spark.read.options(inferSchema=True, multiLine=True, delimiter="},", header=False).json("/Users/christian/Desktop/Data/W-client-27NOV-04DIC.json")

# %%
#W-client-27NOV-04DIC

dfPPCW=spark.createDataFrame(dfPPCW.collect()[0])
a=[]
b=[]
c=[]
d=[]
g=[]
e='SG'
def normaliza(data_structure):
    f=1
    for (index, item) in enumerate(data_structure):
        if len(data_structure.collect()[0][index][1][0]) != 0 : 
            b.append(data_structure.collect()[0][index][0])
            a.append(data_structure.collect()[0][index][1][0])
            c.append(f)
            d.append(e)
            g.append('SF')

            f+=1
    return data_structure


dftest=normaliza(dfPPCW)
dfPPCW=spark.createDataFrame(zip(c, b, a, g, d), schema=['no','text','user','date','group'])

dfPPCW.show()
dfPPCW.summary().show()
# Out:
# +---+--------------------+--------------------+----+-----+
# | no|                text|                user|date|group|
# +---+--------------------+--------------------+----+-----+
# |  1|Análisis de senti...|c845ff51-a267-41e...|  SF|   SG|
# |  2|Análisis de lengu...|4798cbb9-5c6c-492...|  SF|   SG|
# |  3|Recopilación de r...|0a75261b-8cbd-43f...|  SF|   SG|
# |  4|Análisis de senti...|0a75261b-8cbd-43f...|  SF|   SG|
# |  5|Recopilación de r...|0a75261b-8cbd-43f...|  SF|   SG|
# |  6|Análisis de lengu...|0a75261b-8cbd-43f...|  SF|   SG|
# |  7|Recopilación de r...|b5dd31fb-513a-4cc...|  SF|   SG|
# |  8|Recopilación de r...|7e8598a2-6bb9-45d...|  SF|   SG|
# |  9|Análisis de lengu...|c845ff51-a267-41e...|  SF|   SG|
# | 10|Análisis de lengu...|1e1c8af4-1598-4aa...|  SF|   SG|
# | 11|Recopilación de r...|1e1c8af4-1598-4aa...|  SF|   SG|
# | 12|Recopilación de r...|1e1c8af4-1598-4aa...|  SF|   SG|
# | 13|Análisis de lengu...|1e1c8af4-1598-4aa...|  SF|   SG|
# ...

# %%
#Resultado General

from functools import reduce
from pyspark.sql import DataFrame

# create list of dataframes
#df vacios: df2WF, df3WF, df6WF, df7WF
dfG = [df1, df2, df2WR, df3, df3WR, df4, df4WR, df4WF, df5, df5WR, df5WF, df6, df6WR, df7, df7WR, dfPPCW]

# create merged dataframe
dfG = reduce(DataFrame.unionAll, dfG)

dfG.show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  2|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  3|Okay, Fer 🙃 ¿Me ...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  4|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  5|Excelente 👌, aho...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  6|¿Quieres comenzar...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  7|Sí acepto los tér...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  8|¿Qué tema quieres...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  9|¿Cómo te ves en 2...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# | 10|¿Qué preferirías?...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# ...

# %%
#Resultado General

from pyspark.sql import functions as F
from pyspark.sql.window import Window

dfG = dfG.drop("no")

w = Window().partitionBy().orderBy("text")
dfG = dfG.withColumn('no',F.row_number().over(w))
dfG=dfG.select('no','text','user','date','group')
dfG.show()
dfG.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|                    |0d3d89d6-876f-490...|2020-12-03T17:20:...|   1B|
# |  2| Angel Jael Gonzá...|3fb489f8-789d-445...|2020-12-01T17:08:...|   2B|
# |  3|1.1.3 Default Fal...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  4|1.1.3 Default Fal...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  5|1.1.3 Default Fal...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  6|1.1.3 Default Fal...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  7|1.1.3 Default Fal...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  8|1.1.3 Default Fal...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  9|1.1.3 Default Fal...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# ...

# %%
#BD completa de textos

dfG.select('no','text','user','date','group') \
 .write \
 .save("/Users/christian/Desktop/estudioCompleto.json",format="json")

# %%
#BD completa de textos

dfG.select('no','text','user','date','group') \
 .write \
 .save("/Users/christian/Desktop/estudioCompleto.csv",format="csv")

# %%
#Resultado General solo Interacciones sin Repetir

from functools import reduce
from pyspark.sql import DataFrame

# create list of dataframes
#No se toma en cuenta WF ni WR
dfGI = [df1, df2, df3, df4, df5, df6, df7, dfPPCW]

# create merged dataframe
dfGI = reduce(DataFrame.unionAll, dfGI)

dfGI.show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|Sí acepto los tér...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  2|✌️ 😄 para comenz...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  3|Okay, Fer 🙃 ¿Me ...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  4|Muy bien 😄 ¿Me p...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  5|Excelente 👌, aho...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  6|¿Quieres comenzar...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  7|Sí acepto los tér...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  8|¿Qué tema quieres...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  9|¿Cómo te ves en 2...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# | 10|¿Qué preferirías?...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# ...

# %%
#Resultado General solo Interacciones sin Repetir

from pyspark.sql import functions as F
from pyspark.sql.window import Window

dfGI = dfGI.drop("no")

w = Window().partitionBy().orderBy("text")
dfGI = dfGI.withColumn('no',F.row_number().over(w))
dfGI=dfGI.select('no','text','user','date','group')
dfGI.show()
dfGI.summary().show()
# Out:
# +---+--------------------+--------------------+--------------------+-----+
# | no|                text|                user|                date|group|
# +---+--------------------+--------------------+--------------------+-----+
# |  1|                    |0d3d89d6-876f-490...|2020-12-03T17:20:...|   1B|
# |  2| Angel Jael Gonzá...|3fb489f8-789d-445...|2020-12-01T17:08:...|   2B|
# |  3|1.1.3 Default Fal...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  4|1.1.3 Default Fal...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  5|1.1.3 Default Fal...|mobile_app_dialog...|Thu Nov 19 2020 0...|   3A|
# |  6|1.1.3 Default Fal...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  7|1.1.3 Default Fal...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  8|1.1.3 Default Fal...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# |  9|1.1.3 Default Fal...|mobile_app_dialog...|Fri Nov 27 2020 1...|   1A|
# ...

# %%
#BD completa de interacciones

dfGI.select('no','text','user','date','group') \
 .write \
 .save("/Users/christian/Desktop/estudioInteracciones.json",format="json")

# %%
#BD completa de interacciones

dfG.select('no','text','user','date','group') \
 .write \
 .save("/Users/christian/Desktop/estudioInteracciones.csv",format="csv")
